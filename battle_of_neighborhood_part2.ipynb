# %%
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim

# %%
address = 'New Delhi'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Latitude and longitude of '+address+' are {}, {}.'.format(latitude, longitude))
# Out:
# c:\users\gunneet\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# Latitude and longitude of New Delhi are 28.6141793, 77.2022662.

# %%
import requests 
import pandas as pd 
import numpy as np 
import random 

from pandas.io.json import json_normalize

import folium # plotting library

# %%
CLIENT_ID = 'PJSH5MWVM5ZG2BV1DNMWCEPPBP0JUSBJOPVMC53ZB4SK5WHI' # your Foursquare ID
CLIENT_SECRET = 'VWQ31DWH02VNJYAAUGPUTS4KKM4KPJ5VRC5DXGI0EXKP1D5S' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PJSH5MWVM5ZG2BV1DNMWCEPPBP0JUSBJOPVMC53ZB4SK5WHI
# CLIENT_SECRET:VWQ31DWH02VNJYAAUGPUTS4KKM4KPJ5VRC5DXGI0EXKP1D5S

# %%
search_query = 'subway'
radius = 5000
url = 'https://api.foursquare.com/v2/venues/search?client_id=PJSH5MWVM5ZG2BV1DNMWCEPPBP0JUSBJOPVMC53ZB4SK5WHI&client_secret=VWQ31DWH02VNJYAAUGPUTS4KKM4KPJ5VRC5DXGI0EXKP1D5S&ll=28.6141793,77.2022662&v=20190202&query=subway&radius=5000&limit=20'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=PJSH5MWVM5ZG2BV1DNMWCEPPBP0JUSBJOPVMC53ZB4SK5WHI&client_secret=VWQ31DWH02VNJYAAUGPUTS4KKM4KPJ5VRC5DXGI0EXKP1D5S&ll=28.6141793,77.2022662&v=20190202&query=subway&radius=5000&limit=20'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c793d10db04f505a0896714'},
#  'response': {'venues': [{'id': '4c738bc14bc4236a4b27ce7a',
#     'name': 'Subway',
#     'location': {'lat': 28.631486280358768,
#      'lng': 77.22217665238381,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.631486280358768,
#        'lng': 77.22217665238381}],
#      'distance': 2738,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551449360',
#     'hasPerk': False},
#    {'id': '4ce7a4fbfe90a35df4a13d0e',
#     'name': 'Subway',
#     'location': {'address': 'Khan Market',
#      'lat': 28.5995844497909,
#      'lng': 77.22618510662795,
# ...

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head(20)
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 1   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 2   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 3   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 4   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 5   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 6                                                  []    False
# 7   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 8   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 9   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 10  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 11  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 12  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 13  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# ...

# %%
venue_id = '51e18213498ea1b0552d01a9' # ID of subway in kalkaji, new delhi
url = 'https://api.foursquare.com/v2/venues/51e18213498ea1b0552d01a9?client_id=PJSH5MWVM5ZG2BV1DNMWCEPPBP0JUSBJOPVMC53ZB4SK5WHI&client_secret=VWQ31DWH02VNJYAAUGPUTS4KKM4KPJ5VRC5DXGI0EXKP1D5S&v=20190219'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/51e18213498ea1b0552d01a9?client_id=PJSH5MWVM5ZG2BV1DNMWCEPPBP0JUSBJOPVMC53ZB4SK5WHI&client_secret=VWQ31DWH02VNJYAAUGPUTS4KKM4KPJ5VRC5DXGI0EXKP1D5S&v=20190219'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '51e18213498ea1b0552d01a9',
#  'name': 'Subway',
#  'contact': {'phone': '+911141637000', 'formattedPhone': '+91 11 4163 7000'},
#  'location': {'address': 'Block K',
#   'crossStreet': 'Kalkaji',
#   'lat': 28.603098219384986,
#   'lng': 77.22393616316096,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 28.603098219384986,
#     'lng': 77.22393616316096}],
#   'postalCode': '110019',
#   'cc': 'IN',
#   'city': 'New Delhi',
#   'state': 'Delhi',
#   'country': 'India',
#   'formattedAddress': ['Block K (Kalkaji)',
#    'New Delhi 110019',
#    'Delhi',
#    'India']},
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.5

# %%
url = 'https://api.foursquare.com/v2/venues/trending?client_id=PJSH5MWVM5ZG2BV1DNMWCEPPBP0JUSBJOPVMC53ZB4SK5WHI&client_secret=VWQ31DWH02VNJYAAUGPUTS4KKM4KPJ5VRC5DXGI0EXKP1D5S&ll=28.603098219384986,77.22393616316096&v=20190219'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c793d38351e3d13aba44fa3'},
#  'response': {'venues': []}}
